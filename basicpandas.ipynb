# %% [markdown]
# <a href="https://colab.research.google.com/github/subhu6371/apnacollege-demo/blob/main/basicpandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SERIES(ONE DIMENSIONAL)

# %%
import pandas as pd

# %%
s= pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name="calories"

# %%
s
# Out:
# apple        10
# banana       20
# grapes       30
# orange       40
# stawberry    50
# Name: calories, dtype: int64

# %%
s[0:3]
# Out:
# apple     10
# banana    20
# grapes    30
# Name: calories, dtype: int64

# %%
s.iloc[[1,3,4]]
# Out:
# banana       20
# orange       40
# stawberry    50
# Name: calories, dtype: int64

# %%
index=["a","b","c","d","e"]

# %%
s.index=index
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: calories, dtype: int64

# %%
s['b']
# Out:
# np.int64(20)

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
#loc->label based indexing
s.loc['c']
# Out:
# np.int64(30)

# %%
s['b':'e']
# Out:
# b    20
# c    30
# d    40
# e    50
# Name: calories, dtype: int64

# %%
fruit_protein={
    "avocado":2.0,
    "guava":2.6,
    "blackbaries":2.0,
     "oranges":0.9,
     "banana":1.1,
     "apples":0.3,
     "kiwi":1.1,
     "pomegranetes":1.7,
     "mango":0.8,
     "cherries":1.0,


}

# %%
s2=pd.Series(fruit_protein,name="protein")
s2
# Out:
# avocado         2.0
# guava           2.6
# blackbaries     2.0
# oranges         0.9
# banana          1.1
# apples          0.3
# kiwi            1.1
# pomegranetes    1.7
# mango           0.8
# cherries        1.0
# Name: protein, dtype: float64

# %%
#conditional selection
s2>1
# Out:
# avocado          True
# guava            True
# blackbaries      True
# oranges         False
# banana           True
# apples          False
# kiwi             True
# pomegranetes     True
# mango           False
# cherries        False
# Name: protein, dtype: bool

# %%
s2[s2>1]
# Out:
# avocado         2.0
# guava           2.6
# blackbaries     2.0
# banana          1.1
# kiwi            1.1
# pomegranetes    1.7
# Name: protein, dtype: float64

# %%
#logical operator
[(s2>1) & (s2<2)]
# Out:
# [avocado         False
#  guava           False
#  blackbaries     False
#  oranges         False
#  banana           True
#  apples          False
#  kiwi             True
#  pomegranetes     True
#  mango           False
#  cherries        False
#  Name: protein, dtype: bool]

# %%
s2[(s2>1) & (s2<2)]# also we can perform or operation |
# Out:
# banana          1.1
# kiwi            1.1
# pomegranetes    1.7
# Name: protein, dtype: float64

# %%
#not opearation
s2[~(s2>1)]
# Out:
# oranges     0.9
# apples      0.3
# mango       0.8
# cherries    1.0
# Name: protein, dtype: float64

# %%
# modifying the series
s2["mango"]=2.9
s2
# Out:
# avocado         2.0
# guava           2.6
# blackbaries     2.0
# oranges         0.9
# banana          1.1
# apples          0.3
# kiwi            1.1
# pomegranetes    1.7
# mango           2.9
# cherries        1.0
# Name: protein, dtype: float64

# %% [markdown]
# # DATAFRAME(2D)

# %%
import numpy as np
data= {
    "Name":["alice","bob","charlie","david","eve","alice"],
    "Age":[25,30,35, np.nan,29,25],
    "Department":["hr","it","finance","it","hr","hr"],
    "Salary":[50000,60000,70000,62000,np.nan,50000]
}

# %%
data
# Out:
# {'Name': ['alice', 'bob', 'charlie', 'david', 'eve', 'alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['hr', 'it', 'finance', 'it', 'hr', 'hr'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df= pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    alice  25.0         hr  50000.0
# 1      bob  30.0         it  60000.0
# 2  charlie  35.0    finance  70000.0
# 3    david   NaN         it  62000.0
# 4      eve  29.0         hr      NaN
# 5    alice  25.0         hr  50000.0

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  alice  25.0         hr  50000.0
# 1    bob  30.0         it  60000.0

# %%
df.tail(3)
# Out:
#     Name   Age Department   Salary
# 3  david   NaN         it  62000.0
# 4    eve  29.0         hr      NaN
# 5  alice  25.0         hr  50000.0

# %%
df.loc[1:3,["Age","Department"]]
# Out:
#     Age Department
# 1  30.0         it
# 2  35.0    finance
# 3   NaN         it
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Department').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      bob  30.0         it  60000.0
# 2  charlie  35.0    finance  70000.0

# %%
df[["Age","Department"]]
# Out:
#     Age Department
# 0  25.0         hr
# 1  30.0         it
# 2  35.0    finance
# 3   NaN         it
# 4  29.0         hr
# 5  25.0         hr

# %%
df.drop("Age",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-fd6c443967ac> in <cell line: 0>()
# ----> 1 df.drop("Age",axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#       Name Department   Salary
# 0    alice         hr  50000.0
# 1      bob         it  60000.0
# 2  charlie    finance  70000.0
# 3    david         it  62000.0
# 4      eve         hr      NaN
# 5    alice         hr  50000.0

# %%
df.drop("Age",axis=1,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-836f2f9172ae> in <cell line: 0>()
# ----> 1 df.drop("Age",axis=1,inplace=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
# Recreate the DataFrame from the original data
data = {
    "Name":["alice","bob","charlie","david","eve","alice"],
    "Age":[25,30,35, np.nan,29,25],
    "Department":["hr","it","finance","it","hr","hr"],
    "Salary":[50000,60000,70000,62000,np.nan,50000]
}

df = pd.DataFrame(data)

# Display the DataFrame to confirm the 'Age' column is back
print(df)
# Out:
#       Name   Age Department   Salary
# 0    alice  25.0         hr  50000.0
# 1      bob  30.0         it  60000.0
# 2  charlie  35.0    finance  70000.0
# 3    david   NaN         it  62000.0
# 4      eve  29.0         hr      NaN
# 5    alice  25.0         hr  50000.0

# %%
df.shape# the index column not be counted
# Out:
# (6, 4)

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
# Recreate the DataFrame from the original data
import numpy as np
import pandas as pd
data = {
    "Name":["alice","bob","charlie","david","eve","alice"],
    "Age":[25,30,35, np.nan,29,25],
    "Department":["hr","it","finance","it","hr","hr"],
    "Salary":[50000,60000,70000,62000,np.nan,50000]
}

df = pd.DataFrame(data)

# Display the DataFrame to confirm the 'Age' column is back
print(df)
# Out:
#       Name   Age Department   Salary
# 0    alice  25.0         hr  50000.0
# 1      bob  30.0         it  60000.0
# 2  charlie  35.0    finance  70000.0
# 3    david   NaN         it  62000.0
# 4      eve  29.0         hr      NaN
# 5    alice  25.0         hr  50000.0

# %%
df["Salary"]=df["Salary"]+5000

# %%
df["Salary"]
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4        NaN
# 5    55000.0
# Name: Salary, dtype: float64

# %%
#renaming columns
df.rename(columns={"Department":"Dept"},inplace=True)

# %%
df
# Out:
#       Name   Age     Dept   Salary  Salarty
# 0    alice  25.0       hr  55000.0  55000.0
# 1      bob  30.0       it  65000.0  65000.0
# 2  charlie  35.0  finance  75000.0  75000.0
# 3    david   NaN       it  67000.0  67000.0
# 4      eve  29.0       hr      NaN      NaN
# 5    alice  25.0       hr  55000.0  55000.0

# %%
df["Salary"].unique()
# Out:
# array([55000., 65000., 75000., 67000.,    nan])

# %%
df["Dept"].value_counts()
# Out:
# Dept
# hr         3
# it         2
# finance    1
# Name: count, dtype: int64

# %%
df["promoted_salary"]=df["Salary"]*10

# %%
df
# Out:
#       Name   Age     Dept   Salary  Salarty  promoted_salary
# 0    Alice  25.0       hr  55000.0  55000.0         550000.0
# 1    starc  30.0       it  65000.0  65000.0         650000.0
# 2  charlie  35.0  finance  75000.0  75000.0         750000.0
# 3    starc   NaN       it  67000.0  67000.0         670000.0
# 4      eve  29.0       hr      NaN      NaN              NaN
# 5    Alice  25.0       hr  55000.0  55000.0         550000.0

# %%
#Data cleaning
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# Salarty            1
# promoted_salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age     Dept   Salary  Salarty  promoted_salary
# 0    alice  25.0       hr  55000.0  55000.0         550000.0
# 1      bob  30.0       it  65000.0  65000.0         650000.0
# 2  charlie  35.0  finance  75000.0  75000.0         750000.0
# 5    alice  25.0       hr  55000.0  55000.0         550000.0

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df["Salary"].fillna(df["Salary"].median())
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4    65000.0
# 5    55000.0
# Name: Salary, dtype: float64

# %%
df["Name"]=df["Name"].replace("kl","starc")#bob->starc

# %%
df
# Out:
#       Name   Age     Dept   Salary  Salarty  promoted_salary
# 0    Alice  25.0       hr  55000.0  55000.0         550000.0
# 1    starc  30.0       it  65000.0  65000.0         650000.0
# 2  charlie  35.0  finance  75000.0  75000.0         750000.0
# 3    starc   NaN       it  67000.0  67000.0         670000.0
# 4      eve  29.0       hr      NaN      NaN              NaN
# 5    Alice  25.0       hr  55000.0  55000.0         550000.0

# %%
  #Duplicates
  df_dup=df[df.duplicated(keep="first")]
  df_dup
# Out:
#     Name   Age Dept   Salary  Salarty  promoted_salary
# 5  Alice  25.0   hr  55000.0  55000.0         550000.0

# %%
#invalid values
#lambda->python
df["promoted_salary"]=df["promoted_salary"].apply(lambda x:x*2 if x>600000 else x)

# %%
df
# Out:
#       Name   Age     Dept   Salary  Salarty  promoted_salary
# 0    Alice  25.0       hr  55000.0  55000.0         550000.0
# 1    starc  30.0       it  65000.0  65000.0        1300000.0
# 2  charlie  35.0  finance  75000.0  75000.0        1500000.0
# 3    starc   NaN       it  67000.0  67000.0        1340000.0
# 4      eve  29.0       hr      NaN      NaN              NaN
# 5    Alice  25.0       hr  55000.0  55000.0         550000.0

# %%
#apply and lambda
def multiplying_age(x)
return x*2
df["Age"]=df["Age"].apply(multiplying_age)
# Out:
#   File "<ipython-input-57-69a9796eae61>", line 2
#     def multiplying_age(x)
#                           ^
# SyntaxError: expected ':'

# %%
#joins  and merges
#pd.concat([df,df2])->horizontaly combine
#pd.merge(df,df2)->vertically combine

# %%
#how to upload excel file
'''
data=pd.read_csv("data.csv/copy the path")
'''
